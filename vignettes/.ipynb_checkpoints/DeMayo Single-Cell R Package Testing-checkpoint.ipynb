# %% [markdown]
# # DeMayo single-cell R package testing
#
# This notebook contains some examples about how to use the functions in the dmSC R package. See the below section for notes about specific tasks.

# %%
# Ensure you're using the right version of Python for reticulate (important for adobo!)
Sys.setenv(RETICULATE_PYTHON = "/ddn/gs1/home/laispf/usr/local/miniforge3/envs/r/bin/python3.8")

library(dplyr)
devtools::load_all("../packages/dmSC") # I call this in my code, but instead use the below lines...

# devtools::install_github("petronian/demayo-bioinformatics-utilities",
#                          subdir = "packages/dmSC/")
# library(dmSC)
# Out:
# ℹ Loading dmSC

# %% [markdown]
# ## Setting locations for checking for DeMayo lab datasets
#
# These datasets are proprietary, so this will only work for datasets within the NIEHS.

# %%
# Set the paths to search for and list the packages available.
# For scigate/Linux, paths will look like /ddn/gs1/home/...
# For wine/Windows, paths will look like \\wine\..., change \ to /.
# This example was used on scigate.
dmSC::set_datapath("/ddn/gs1/home/laispf/package-repo/r/dmSC/data")

# List all available datasets.
dmSC::list_data()

# Then install and load a package.
dmSC::install_data("rlTRIM28", verbose = TRUE)

# Then load the data you just installed.
data("rlTRIM28")

rlTRIM28
# Out:
# [1] "Path currently includes: "
# [2] "/ddn/gs1/home/laispf/package-repo/r/dmSC/data"
#    file                   installed
# 1  kwUtMes                FALSE
# 2  mca3AdultUterus         TRUE
# 3  rlTRIM28.proc           TRUE
# 4  rlTRIM28                TRUE
# 5  rlTRIM28Mes             TRUE
# 6  srfKO_RM1               TRUE
# 7  utGD3.5TRIM28.All      FALSE
# 8  utGD3.5TRIM28.KO       FALSE
# 9  utGD3.5TRIM28          FALSE
# 10 utSrfDpc3.5Control      TRUE
# 11 utSrfDpc3.5KO           TRUE
# 12 utSrfDpc3.5SpatialFlox  TRUE
# 13 utSrfDpc3.5SpatialKO    TRUE
#    sources
# 1  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 2  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 3  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 4  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 5  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 6  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 7  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 8  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 9  /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 10 /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 11 /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 12 /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# 13 /ddn/gs1/home/laispf/package-repo/r/dmSC/data
# [1] "Checking folder /ddn/gs1/home/laispf/packages/prod/packages/dmSC/data for existing data."
# [1] "Data 'rlTRIM28' already installed. Set 'reinstall = TRUE' if you wish to overwrite the existing file."
# An object of class Seurat
# 21528 features across 9872 samples within 1 assay
# Active assay: RNA (21528 features, 1000 variable features)
#  4 dimensional reductions calculated: pca, umap, harmony, umap10

# %% [markdown]
# ## Mapping gene symbols to ENSEMBL names
#
# Note that not all genes will map to ENSEMBL names. These genes will be replaced with `NA` values.

# %%
# Download and load a series of sample gene names.
system2("curl", c("-O", "https://raw.githubusercontent.com/zixuans/SurvNet/master/Data/dataset6/gene_names_org2.txt"))
gene_names <- as.vector(unlist(read.table("gene_names_org2.txt")))
head(gene_names)
length(gene_names)
# Out:
# [1] "0610007C21Rik" "0610009D07Rik" "1110002B05Rik" "1110003E01Rik"
# [5] "1110004F10Rik" "1500032L24Rik"
# [1] 1046

# %%
# Rename the gene names from symbols to ENSEMBL.
ensembl_names <- dmSC::apply_mapper(gene_names, to_ensembl = TRUE)
ensembl_names_no_nas <- ensembl_names[!is.na(ensembl_names)]
head(ensembl_names)
head(ensembl_names_no_nas)
# Out:
# [1] NA                   NA                   NA
# [4] NA                   "ENSMUSG00000030663" NA
# [1] "ENSMUSG00000030663" "ENSMUSG00000100147" "ENSMUSG00000054091"
# [4] "ENSMUSG00000029559" "ENSMUSG00000018451" "ENSMUSG00000006299"

# %% [markdown]
# ## Plot IPA dot plots
#
# This can be used with any sort of data that can be arranged into the format of `ipa_tbl`. In the DeMayo lab, though, IPA is the most common way that this comes up.

# %%
# Make some sample data.
ipa_tbl <- data.frame(pathways = c("Cytokine storm", "Fibrosis", "B-cell signaling", "Eukaryotic translation initiation"),
                      zScores = runif(n = 4, min = -5, max = 5),
                      negLog10Ps = runif(n = 4, min = 2, max = 10),
                      ratios = runif(n = 4, min = 0, max = 1))
ipa_tbl
# Out:
#   pathways                          zScores   negLog10Ps ratios
# 1 Cytokine storm                     2.168641 9.468978   0.48964096
# 2 Fibrosis                          -3.000835 2.451704   0.09977158
# 3 B-cell signaling                  -4.047409 3.428156   0.83065182
# 4 Eukaryotic translation initiation  4.671601 4.486813   0.95928502

# %%
# Plot the dotplot.
dmSC::ipa_dotplot(tbl = ipa_tbl,
                  z_score_colname = "zScores",
                  ratio_colname = "ratios",
                  neg_log_p_colname = "negLog10Ps",
                  y_axis_label_colname = "pathways")
# Out:
# plot without title

# %% [markdown]
# ## Plot a split heatmap
#
# Note that the gene types don't actually display on the split heatmap.

# %%
# Make some random data for the split heatmap.
gene_tbl <- data.frame(genes = gene_names[1:15],
                       sample_1 = runif(n = 15, min = 0, max = 5),
                       sample_2 = runif(n = 15, min = 0, max = 5),
                       sample_3 = runif(n = 15, min = 0, max = 5),
                       type = rep(c(1,2,3), 5))
head(gene_tbl)
# Out:
#   genes         sample_1  sample_2  sample_3  type
# 1 0610007C21Rik 1.6861614 4.3360757 1.6344867 1
# 2 0610009D07Rik 4.8806341 2.8115291 2.9577214 2
# 3 1110002B05Rik 0.4050635 1.7977374 2.1976260 3
# 4 1110003E01Rik 4.0677105 1.8029832 0.4837574 1
# 5 1110004F10Rik 0.2602917 3.8049857 0.9988136 2
# 6 1500032L24Rik 3.0267619 0.5687658 2.3397304 3

# %%
# Plot the split heatmap.
dmSC::create_split_heatmap(assay = gene_tbl,
                           type_column = "type",
                           symbol_column = "genes",
                           cluster_rows = TRUE,
                           cluster_cols = TRUE)
# Out:
# plot without title

# %% [markdown]
# ## Impute cell types using `adobo`
#
# This is a manual marker-based cell type imputation method. Essentially, you tell the algorithm the genes that are markers of cell types in a particular cluster, and `adobo` tells you what is what.
#
# See this link for more information: https://oscar-franzen.github.io/adobo/#cell-type-prediction
#
# Also note that you need to set the `RETICULATE_PYTHON` environment variable; see the top of this file.

# %%
# Make a SAMPLE single-cell dataset with Seurat.
# Ordinarily, you'd have this already.

random_st_obj <- function (n_genes, n_cells, sample_name_len = 25, max_counts = 100) {

    sample_gene_names <- sample(gene_names, n_genes, replace = FALSE)
    sample_cell_names_lambda <- (function (x) paste0(sample(c("A","C","T","G"), 25, replace = TRUE), collapse = ''))
    sample_cell_names <- sapply(1:n_cells, sample_cell_names_lambda)

    mtx <- matrix(sample(0:max_counts, n_genes * n_cells, replace = TRUE), nrow = n_genes)
    rownames(mtx) <- sample_gene_names
    colnames(mtx) <- sample_cell_names
    
    st_obj <- Seurat::CreateSeuratObject(mtx)

    # Replace all of these calls with 'st_obj <- Seurat::SCTransform(st_obj)'
    st_obj <- Seurat::NormalizeData(st_obj)
    st_obj <- Seurat::ScaleData(st_obj, verbose = FALSE)
    st_obj <- Seurat::FindVariableFeatures(st_obj, verbose = FALSE)

    # Visualize cells
    st_obj <- Seurat::RunPCA(st_obj, verbose = FALSE)
    st_obj <- Seurat::RunUMAP(st_obj, dims = 1:10, verbose = FALSE)
    st_obj <- Seurat::FindNeighbors(st_obj, dims = 1:10, verbose = FALSE)
    st_obj <- Seurat::FindClusters(st_obj, verbose = FALSE)

    return(st_obj)
}
                                 
n_genes <- 1000
n_cells <- 1000

st_tgt <- random_st_obj(n_genes = n_genes, n_cells = n_cells) # to impute against
st_ref <- random_st_obj(n_genes = n_genes / 2, n_cells = n_cells * 3) # to impute, no need for same size
st_tgt$seurat_clusters <- paste0("tgtcluster", st_tgt$seurat_clusters)
st_ref$seurat_clusters <- paste0("refcluster", st_ref$seurat_clusters)

# Plot the object.
Seurat::DimPlot(st_tgt, label = TRUE, group.by = "seurat_clusters") + 
Seurat::DimPlot(st_ref, label = TRUE, group.by = "seurat_clusters")
                                 
# Get the top marker genes for each.
# Don't use the logfc.
ref_markers <- Seurat::FindAllMarkers(st_ref, logfc.threshold = 0, only.pos = TRUE, verbose = FALSE)
ref_markers <- ref_markers %>% group_by(cluster) %>% slice_max(order_by = avg_log2FC, n = 20)
slice_max(ref_markers, order_by = avg_log2FC, n = 1)
# Out:
#   p_val        avg_log2FC pct.1 pct.2 p_val_adj    cluster gene
# 1 2.486519e-09 0.2179037  0.998 0.987 1.243259e-06 0       Rnasek
# 2 3.667975e-07 0.2041461  0.998 0.988 1.833988e-04 1       Elovl1
# 3 2.053098e-07 0.2080890  0.993 0.987 1.026549e-04 2       Adi1
# 4 6.786292e-12 0.2723225  1.000 0.986 3.393146e-09 3       Tmem66
# 5 1.111271e-06 0.2080016  0.995 0.989 5.556354e-04 4       Cd82
# 6 3.020274e-08 0.2613345  1.000 0.986 1.510137e-05 5       Mtdh
# 7 2.781326e-07 0.2424349  1.000 0.989 1.390663e-04 6       Zeb2
# 8 1.848799e-06 0.2412994  0.996 0.992 9.243997e-04 7       Rraga
# plot without title

# %%
# Do the imputation. Since we used random data for each of these, adobo will likely not know
# what our output clusters look like since all of them look the same. This is exepcted.
# With more informative clusters, you'd get 'refclusterX' in the adobo_clusters section.
# THIS TUTORIAL IS JUST TO SHOW HOW TO USE THE FUNCTION.

st_tgt_imputed <- dmSC::adobo_impute(st_tgt,
                                     gene_symbols = ref_markers$gene,
                                     cell_types = ref_markers$cluster,
                                     cluster_slot = "seurat_clusters")

head(st_tgt) # before impute
head(st_tgt_imputed[[]]) # after impute
# Out:
#                           orig.ident    nCount_RNA nFeature_RNA RNA_snn_res.0.8
# CATAGATGATTGTCACGCTGCATTC SeuratProject 49365      990          3
# CAATGCGTGCTATATGACCTAAAGC SeuratProject 49373      990          4
# AGGCTCTCCTGCTAAGTACTTTGGG SeuratProject 49746      986          3
# GGTAAGATCAGAAAACGAGCCAAGG SeuratProject 48774      988          4
# GCACCTAAAGGCCATCTTATCTTCC SeuratProject 49956      990          3
# GACGGTTAATAGGCTCACAGGGGTC SeuratProject 50674      991          2
# TATGTACTTAACTATGCGGTAATTT SeuratProject 49583      989          2
# TCTTTCTGTTATGAAAAAATACGAG SeuratProject 49215      990          0
# GCAGAGGGTCTAGAAATAGTTAGTC SeuratProject 48238      989          3
# ACAGCTACAGAAATGTGTTTTTAGC SeuratProject 50789      992          0
#                           seurat_clusters
# CATAGATGATTGTCACGCTGCATTC tgtcluster3
# CAATGCGTGCTATATGACCTAAAGC tgtcluster4
# AGGCTCTCCTGCTAAGTACTTTGGG tgtcluster3
# GGTAAGATCAGAAAACGAGCCAAGG tgtcluster4
# GCACCTAAAGGCCATCTTATCTTCC tgtcluster3
# GACGGTTAATAGGCTCACAGGGGTC tgtcluster2
# TATGTACTTAACTATGCGGTAATTT tgtcluster2
# TCTTTCTGTTATGAAAAAATACGAG tgtcluster0
# GCAGAGGGTCTAGAAATAGTTAGTC tgtcluster3
# ACAGCTACAGAAATGTGTTTTTAGC tgtcluster0
#                           orig.ident    nCount_RNA nFeature_RNA RNA_snn_res.0.8
# CATAGATGATTGTCACGCTGCATTC SeuratProject 49365      990          3
# CAATGCGTGCTATATGACCTAAAGC SeuratProject 49373      990          4
# AGGCTCTCCTGCTAAGTACTTTGGG SeuratProject 49746      986          3
# GGTAAGATCAGAAAACGAGCCAAGG SeuratProject 48774      988          4
# GCACCTAAAGGCCATCTTATCTTCC SeuratProject 49956      990          3
# GACGGTTAATAGGCTCACAGGGGTC SeuratProject 50674      991          2
#                           seurat_clusters adobo_clusters
# CATAGATGATTGTCACGCTGCATTC tgtcluster3     NA
# CAATGCGTGCTATATGACCTAAAGC tgtcluster4     NA
# AGGCTCTCCTGCTAAGTACTTTGGG tgtcluster3     NA
# GGTAAGATCAGAAAACGAGCCAAGG tgtcluster4     NA
# GCACCTAAAGGCCATCTTATCTTCC tgtcluster3     NA
# GACGGTTAATAGGCTCACAGGGGTC tgtcluster2     NA

# %% [markdown]
# ## Seurat to single-cell reference matrix (CIBERSORTx)
#
# Create a single-cell reference matrix for use with CIBERSORTx with one function.

# %%
# For example...
head(dmSC::seurat_to_sc_ref(st_tgt_imputed, cluster_colname = "seurat_clusters"))
# Out:
#        c("tgtcluster3", "tgtcluster4", "tgtcluster3", "tgtcluster4", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster0", "tgtcluster3", "tgtcluster0", "tgtcluster5", "tgtcluster3", "tgtcluster1", "tgtcluster3", "tgtcluster1", "tgtcluster0", "tgtcluster3", "tgtcluster2", "tgtcluster0", "tgtcluster5", "tgtcluster1", "tgtcluster4", "tgtcluster1", "tgtcluster1", "tgtcluster4", "tgtcluster0", "tgtcluster1", "tgtcluster0", "tgtcluster4", "tgtcluster2", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster1", \n"tgtcluster2", "tgtcluster1", "tgtcluster1", "tgtcluster3", "tgtcluster2", "tgtcluster1", "tgtcluster1", "tgtcluster5", "tgtcluster3", "tgtcluster1", "tgtcluster3", "tgtcluster0", "tgtcluster5", "tgtcluster2", "tgtcluster1", "tgtcluster0", "tgtcluster4", "tgtcluster1", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster0", "tgtcluster1", "tgtcluster2", "tgtcluster0", "tgtcluster3", "tgtcluster1", "tgtcluster5", "tgtcluster0", "tgtcluster3", "tgtcluster4", "tgtcluster0", "tgtcluster1", "tgtcluster2", \n"tgtcluster2", "tgtcluster1", "tgtcluster2", "tgtcluster2", "tgtcluster4", "tgtcluster3", "tgtcluster3", "tgtcluster0", "tgtcluster2", "tgtcluster1", "tgtcluster0", "tgtcluster2", "tgtcluster4", "tgtcluster4", "tgtcluster3", "tgtcluster0", "tgtcluster1", "tgtcluster0", "tgtcluster4", "tgtcluster0", "tgtcluster0", "tgtcluster1", "tgtcluster4", "tgtcluster0", "tgtcluster0", "tgtcluster1", "tgtcluster2", "tgtcluster2", "tgtcluster5", "tgtcluster0", "tgtcluster3", "tgtcluster3", "tgtcluster2", "tgtcluster4", \n"tgtcluster4", "tgtcluster4", "tgtcluster1", "tgtcluster2", "tgtcluster3", "tgtcluster4", "tgtcluster1", "tgtcluster0", "tgtcluster2", "tgtcluster1", "tgtcluster0", "tgtcluster1", "tgtcluster1", "tgtcluster5", "tgtcluster5", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster2", "tgtcluster1", "tgtcluster2", "tgtcluster2", "tgtcluster0", "tgtcluster2", "tgtcluster4", "tgtcluster0", "tgtcluster0", "tgtcluster1", "tgtcluster4", "tgtcluster0", "tgtcluster1", "tgtcluster3", "tgtcluster5", "tgtcluster4", \n"tgtcluster2", "tgtcluster4", "tgtcluster5", "tgtcluster1", "tgtcluster5", "tgtcluster0", "tgtcluster2", "tgtcluster4", "tgtcluster5", "tgtcluster1", "tgtcluster5", "tgtcluster2", "tgtcluster0", "tgtcluster3", "tgtcluster3", "tgtcluster5", "tgtcluster3", "tgtcluster2", "tgtcluster0", "tgtcluster0", "tgtcluster0", "tgtcluster3", "tgtcluster5", "tgtcluster3", "tgtcluster5", "tgtcluster2", "tgtcluster3", "tgtcluster0", "tgtcluster2", "tgtcluster1", "tgtcluster0", "tgtcluster0", "tgtcluster5", "tgtcluster0", \n"tgtcluster4", "tgtcluster0", "tgtcluster1", "tgtcluster4", "tgtcluster2", "tgtcluster2", "tgtcluster0", "tgtcluster2", "tgtcluster0", "tgtcluster3", "tgtcluster1", "tgtcluster2", "tgtcluster0", "tgtcluster4", "tgtcluster1", "tgtcluster2", "tgtcluster1", "tgtcluster1", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster5", "tgtcluster4", "tgtcluster1", "tgtcluster3", "tgtcluster1", "tgtcluster3", "tgtcluster3", "tgtcluster2", "tgtcluster2", "tgtcluster1", "tgtcluster0", "tgtcluster0", "tgtcluster5", \n"tgtcluster2", "tgtcluster4", "tgtcluster2", "tgtcluster3", "tgtcluster3", "tgtcluster3", "tgtcluster3", "tgtcluster5", "tgtcluster0", "tgtcluster2", "tgtcluster0", "tgtcluster4", "tgtcluster1", "tgtcluster2", "tgtcluster4", "tgtcluster5", "tgtcluster3", "tgtcluster4", "tgtcluster3", "tgtcluster5", "tgtcluster4", "tgtcluster2", "tgtcluster2", "tgtcluster2", "tgtcluster0", "tgtcluster3", "tgtcluster1", "tgtcluster3", "tgtcluster1", "tgtcluster1", "tgtcluster1", "tgtcluster0", "tgtcluster3", "tgtcluster1", \n"tgtcluster0", "tgtcluster3", "tgtcluster0", "tgtcluster3", "tgtcluster1", "tgtcluster0", "tgtcluster0", "tgtcluster0", "tgtcluster4", "tgtcluster1", "tgtcluster3", "tgtcluster1", "tgtcluster2", "tgtcluster0", "tgtcluster4", "tgtcluster1", "tgtcluster3", "tgtcluster5", "tgtcluster3", "tgtcluster2", "tgtcluster3", "tgtcluster3", "tgtcluster0", "tgtcluster0", "tgtcluster0", "tgtcluster1", "tgtcluster3", "t ...
# Vdac2  2.065276                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Prpf19 2.636529                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Atxn10 2.650931                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Tceb1  2.924442                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Lhfpl3 2.561234                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Eif3h  3.056699                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#        <NA>     NA.1      NA.2      NA.3      NA.4      NA.5     NA.6
# Vdac2  2.935106 2.9492645 0.8900251 0.7889377 2.9525777 2.829257 1.447164
# Prpf19 3.046969 2.3464102 1.8124901 1.0301855 2.1164452 3.052500 2.812148
# Atxn10 1.491370 0.6956969 2.1011975 2.6954481 2.3487349 2.458661 2.393916
# Tceb1  2.561084 1.7620746 1.9081732 1.6493698 2.2287528 2.572683 2.736087
# Lhfpl3 2.664978 1.4389672 0.5988964 0.5881780 2.8323028 2.603007 1.987723
# Eif3h  2.796856 1.6527742 2.7312398 2.0022415 0.5818577 2.248197 1.770972
#        NA.7      NA.8     ⋯ <NA>     NA.1     NA.2     NA.3     NA.4
# Vdac2  1.7523298 2.624527 ⋯ 2.194350 2.746077 2.205944 2.230513 2.714793
# Prpf19 2.3349308 2.638696 ⋯ 2.962205 1.232628 1.988616 1.897839 2.829726
# Atxn10 1.0528297 0.000000 ⋯ 2.909292 2.208359 2.981593 2.039169 2.910795
# Tceb1  0.8081854 2.875591 ⋯ 2.962205 2.650686 2.842443 2.090545 2.072991
# Lhfpl3 2.2291772 2.595573 ⋯ 2.691611 2.913256 2.384369 2.935164 2.020198
# Eif3h  0.4836084 1.596932 ⋯ 1.853569 0.000000 2.667160 2.845152 2.780268
#        NA.5      NA.6     NA.7      NA.8     NA.9
# Vdac2  2.4293910 2.346647 2.7474956 1.945048 2.3176212
# Prpf19 1.9700960 2.554382 2.0543330 1.050890 1.6443913
# Atxn10 0.1815515 2.032800 2.8451355 2.803459 2.5903641
# Tceb1  1.7879032 2.420791 0.6932672 1.359344 0.6905077
# Lhfpl3 2.1706496 0.338005 1.7580566 2.463666 1.0950914
# Eif3h  1.5224352 2.713048 2.1043449 2.133075 2.2570290
